# %% [markdown]
# # Excute-argparse-python-script-on-jupyter-notebook
#
# ## Chainer test
#
# - [chainer/examples/mnist/train_mnist.py](https://github.com/chainer/chainer/blob/master/examples/mnist/train_mnist.py)

# %%
#!/usr/bin/env python
import argparse

import chainer
import chainer.functions as F
import chainer.links as L
from chainer import training
from chainer.training import extensions


# Network definition
class MLP(chainer.Chain):

    def __init__(self, n_units, n_out):
        super(MLP, self).__init__()
        with self.init_scope():
            # the size of the inputs to each layer will be inferred
            self.l1 = L.Linear(None, n_units)  # n_in -> n_units
            self.l2 = L.Linear(None, n_units)  # n_units -> n_units
            self.l3 = L.Linear(None, n_out)  # n_units -> n_out

    def forward(self, x):
        h1 = F.relu(self.l1(x))
        h2 = F.relu(self.l2(h1))
        return self.l3(h2)


def main():
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', type=int, default=100,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=20,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=-1,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default='result',
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default='',
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', type=int, default=1000,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()

    print('GPU: {}'.format(args.gpu))
    print('# unit: {}'.format(args.unit))
    print('# Minibatch-size: {}'.format(args.batchsize))
    print('# epoch: {}'.format(args.epoch))
    print('')

    # Set up a neural network to train
    # Classifier reports softmax cross entropy loss and accuracy at every
    # iteration, which will be used by the PrintReport extension below.
    model = L.Classifier(MLP(args.unit, 10))
    if args.gpu >= 0:
        # Make a specified GPU current
        chainer.backends.cuda.get_device_from_id(args.gpu).use()
        model.to_gpu()  # Copy the model to the GPU

    # Setup an optimizer
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(model)

    # Load the MNIST dataset
    train, test = chainer.datasets.get_mnist()

    train_iter = chainer.iterators.SerialIterator(train, args.batchsize)
    test_iter = chainer.iterators.SerialIterator(test, args.batchsize,
                                                 repeat=False, shuffle=False)

    # Set up a trainer
    updater = training.updaters.StandardUpdater(
        train_iter, optimizer, device=args.gpu)
    trainer = training.Trainer(updater, (args.epoch, 'epoch'), out=args.out)

    # Evaluate the model with the test dataset for each epoch
    trainer.extend(extensions.Evaluator(test_iter, model, device=args.gpu))

    # Dump a computational graph from 'loss' variable at the first iteration
    # The "main" refers to the target link of the "main" optimizer.
    trainer.extend(extensions.dump_graph('main/loss'))

    # Take a snapshot for each specified epoch
    frequency = args.epoch if args.frequency == -1 else max(1, args.frequency)
    trainer.extend(extensions.snapshot(), trigger=(frequency, 'epoch'))

    # Write a log of evaluation statistics for each epoch
    trainer.extend(extensions.LogReport())

    # Save two plot images to the result dir
    if args.plot and extensions.PlotReport.available():
        trainer.extend(
            extensions.PlotReport(['main/loss', 'validation/main/loss'],
                                  'epoch', file_name='loss.png'))
        trainer.extend(
            extensions.PlotReport(
                ['main/accuracy', 'validation/main/accuracy'],
                'epoch', file_name='accuracy.png'))

    # Print selected entries of the log to stdout
    # Here "main" refers to the target link of the "main" optimizer again, and
    # "validation" refers to the default name of the Evaluator extension.
    # Entries other than 'epoch' are reported by the Classifier link, called by
    # either the updater or the evaluator.
    trainer.extend(extensions.PrintReport(
        ['epoch', 'main/loss', 'validation/main/loss',
         'main/accuracy', 'validation/main/accuracy', 'elapsed_time']))

    # Print a progress bar to stdout
    trainer.extend(extensions.ProgressBar())

    if args.resume:
        # Resume from a snapshot
        chainer.serializers.load_npz(args.resume, trainer)

    # Run the training
    trainer.run()

# %%
# https://stackoverflow.com/a/30662356

if __name__ == "__main__":
    import sys
    sys.argv = ['-f'] + ["--gpu", "1"]
    main()
# Out:
# GPU: 1
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     254.41 iters/sec. Estimated time to finish: 0:00:46.381780.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     254.59 iters/sec. Estimated time to finish: 0:00:45.956593.
#      total [#.................................................]  3.33%
# this epoch [#################################.................] 66.67%
#        400 iter, 0 epoch / 20 epochs
#     254.61 iters/sec. Estimated time to finish: 0:00:45.559879.
#      total [##................................................]  4.17%
# this epoch [#########################################.........] 83.33%
#        500 iter, 0 epoch / 20 epochs
#     254.56 iters/sec. Estimated time to finish: 0:00:45.175486.
# 1           0.190326    0.0937458             0.942217       0.9696                    2.5362
#      total [##................................................]  5.00%
# this epoch [..................................................]  0.00%
#        600 iter, 1 epoch / 20 epochs
#     213.33 iters/sec. Estimated time to finish: 0:00:53.438272.
#      total [##................................................]  5.83%
# this epoch [########..........................................] 16.67%
#        700 iter, 1 epoch / 20 epochs
#     219.09 iters/sec. Estimated time to finish: 0:00:51.577263.
#      total [###...............................................]  6.67%
# this epoch [################..................................] 33.33%
#        800 iter, 1 epoch / 20 epochs
#     223.52 iters/sec. Estimated time to finish: 0:00:50.106976.
#      total [###...............................................]  7.50%
# this epoch [#########################.........................] 50.00%
#        900 iter, 1 epoch / 20 epochs
#     227.01 iters/sec. Estimated time to finish: 0:00:48.897246.
#      total [####..............................................]  8.33%
# this epoch [#################################.................] 66.67%
#       1000 iter, 1 epoch / 20 epochs
#     229.71 iters/sec. Estimated time to finish: 0:00:47.886209.
#      total [####..............................................]  9.17%
# this epoch [#########################################.........] 83.33%
#       1100 iter, 1 epoch / 20 epochs
#     231.95 iters/sec. Estimated time to finish: 0:00:46.992903.
# 2           0.0722848   0.0807287             0.977499       0.975                     5.27848
#      total [#####.............................................] 10.00%
# this epoch [..................................................]  0.00%
#       1200 iter, 2 epoch / 20 epochs
#     211.46 iters/sec. Estimated time to finish: 0:00:51.074541.
#      total [#####.............................................] 10.83%
# this epoch [########..........................................] 16.67%
#       1300 iter, 2 epoch / 20 epochs
#     214.48 iters/sec. Estimated time to finish: 0:00:49.888321.
#      total [#####.............................................] 11.67%
# this epoch [################..................................] 33.33%
#       1400 iter, 2 epoch / 20 epochs
#     217.26 iters/sec. Estimated time to finish: 0:00:48.788692.
#      total [######............................................] 12.50%
# this epoch [#########################.........................] 50.00%
#       1500 iter, 2 epoch / 20 epochs
#     219.73 iters/sec. Estimated time to finish: 0:00:47.786511.
#      total [######............................................] 13.33%
# this epoch [#################################.................] 66.67%
#       1600 iter, 2 epoch / 20 epochs
#     221.79 iters/sec. Estimated time to finish: 0:00:46.891783.
#      total [#######...........................................] 14.17%
# this epoch [#########################################.........] 83.33%
#       1700 iter, 2 epoch / 20 epochs
#     223.68 iters/sec. Estimated time to finish: 0:00:46.048107.
# 3           0.0487675   0.0775306             0.984232       0.9765                    8.11228
#      total [#######...........................................] 15.00%
# this epoch [..................................................]  0.00%
#       1800 iter, 3 epoch / 20 epochs
#     214.02 iters/sec. Estimated time to finish: 0:00:47.659696.
#      total [#######...........................................] 15.83%
# this epoch [########..........................................] 16.67%
#       1900 iter, 3 epoch / 20 epochs
#     215.84 iters/sec. Estimated time to finish: 0:00:46.794330.
#      total [########..........................................] 16.67%
# this epoch [################..................................] 33.33%
#       2000 iter, 3 epoch / 20 epochs
#     217.66 iters/sec. Estimated time to finish: 0:00:45.942793.
#      total [########..........................................] 17.50%
# this epoch [#########################.........................] 50.00%
#       2100 iter, 3 epoch / 20 epochs
#      219.3 iters/sec. Estimated time to finish: 0:00:45.143715.
#      total [#########.........................................] 18.33%
# this epoch [#################################.................] 66.67%
#       2200 iter, 3 epoch / 20 epochs
#     220.76 iters/sec. Estimated time to finish: 0:00:44.391736.
#      total [#########.........................................] 19.17%
# this epoch [#########################################.........] 83.33%
#       2300 iter, 3 epoch / 20 epochs
#     222.14 iters/sec. Estimated time to finish: 0:00:43.665704.
# 4           0.0355568   0.084215              0.988982       0.9767                    10.8664
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       2400 iter, 4 epoch / 20 epochs
#        215 iters/sec. Estimated time to finish: 0:00:44.651750.
#      total [##########........................................] 20.83%
# this epoch [########..........................................] 16.67%
#       2500 iter, 4 epoch / 20 epochs
#     216.35 iters/sec. Estimated time to finish: 0:00:43.909485.
#      total [##########........................................] 21.67%
# this epoch [################..................................] 33.33%
#       2600 iter, 4 epoch / 20 epochs
#     217.68 iters/sec. Estimated time to finish: 0:00:43.183163.
#      total [###########.......................................] 22.50%
# this epoch [#########################.........................] 50.00%
#       2700 iter, 4 epoch / 20 epochs
#     218.89 iters/sec. Estimated time to finish: 0:00:42.486631.
#      total [###########.......................................] 23.33%
# this epoch [#################################.................] 66.67%
#       2800 iter, 4 epoch / 20 epochs
#     220.06 iters/sec. Estimated time to finish: 0:00:41.807243.
#      total [############......................................] 24.17%
# this epoch [#########################################.........] 83.33%
#       2900 iter, 4 epoch / 20 epochs
#     221.14 iters/sec. Estimated time to finish: 0:00:41.150826.
# 5           0.0261058   0.0875858             0.991131       0.9767                    13.6259
#      total [############......................................] 25.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 5 epoch / 20 epochs
#     215.44 iters/sec. Estimated time to finish: 0:00:41.774210.
#      total [############......................................] 25.83%
# this epoch [########..........................................] 16.67%
#       3100 iter, 5 epoch / 20 epochs
#     216.53 iters/sec. Estimated time to finish: 0:00:41.103521.
#      total [#############.....................................] 26.67%
# this epoch [################..................................] 33.33%
#       3200 iter, 5 epoch / 20 epochs
#      217.6 iters/sec. Estimated time to finish: 0:00:40.441804.
#      total [#############.....................................] 27.50%
# this epoch [#########################.........................] 50.00%
#       3300 iter, 5 epoch / 20 epochs
#      218.6 iters/sec. Estimated time to finish: 0:00:39.799040.
#      total [##############....................................] 28.33%
# this epoch [#################################.................] 66.67%
#       3400 iter, 5 epoch / 20 epochs
#     219.56 iters/sec. Estimated time to finish: 0:00:39.169323.
#      total [##############....................................] 29.17%
# this epoch [#########################################.........] 83.33%
#       3500 iter, 5 epoch / 20 epochs
#     220.44 iters/sec. Estimated time to finish: 0:00:38.559334.
# 6           0.0246534   0.104257              0.991532       0.9747                    16.3858
#      total [###############...................................] 30.00%
# this epoch [..................................................]  0.00%
#       3600 iter, 6 epoch / 20 epochs
#     215.99 iters/sec. Estimated time to finish: 0:00:38.891585.
#      total [###############...................................] 30.83%
# this epoch [########..........................................] 16.67%
#       3700 iter, 6 epoch / 20 epochs
#     216.82 iters/sec. Estimated time to finish: 0:00:38.279923.
#      total [###############...................................] 31.67%
# this epoch [################..................................] 33.33%
#       3800 iter, 6 epoch / 20 epochs
#     217.71 iters/sec. Estimated time to finish: 0:00:37.664526.
#      total [################..................................] 32.50%
# this epoch [#########################.........................] 50.00%
#       3900 iter, 6 epoch / 20 epochs
#     218.53 iters/sec. Estimated time to finish: 0:00:37.066635.
#      total [################..................................] 33.33%
# this epoch [#################################.................] 66.67%
#       4000 iter, 6 epoch / 20 epochs
#      219.3 iters/sec. Estimated time to finish: 0:00:36.480461.
#      total [#################.................................] 34.17%
# this epoch [#########################################.........] 83.33%
#       4100 iter, 6 epoch / 20 epochs
#     220.07 iters/sec. Estimated time to finish: 0:00:35.898160.
# 7           0.0180947   0.0824152             0.993998       0.98                      19.1385
#      total [#################.................................] 35.00%
# this epoch [..................................................]  0.00%
#       4200 iter, 7 epoch / 20 epochs
#     215.72 iters/sec. Estimated time to finish: 0:00:36.158610.
#      total [#################.................................] 35.83%
# this epoch [########..........................................] 16.67%
#       4300 iter, 7 epoch / 20 epochs
#     216.34 iters/sec. Estimated time to finish: 0:00:35.592006.
#      total [##################................................] 36.67%
# this epoch [################..................................] 33.33%
#       4400 iter, 7 epoch / 20 epochs
#     217.11 iters/sec. Estimated time to finish: 0:00:35.004831.
#      total [##################................................] 37.50%
# this epoch [#########################.........................] 50.00%
#       4500 iter, 7 epoch / 20 epochs
#     217.87 iters/sec. Estimated time to finish: 0:00:34.424236.
#      total [###################...............................] 38.33%
# this epoch [#################################.................] 66.67%
#       4600 iter, 7 epoch / 20 epochs
#     218.57 iters/sec. Estimated time to finish: 0:00:33.856818.
#      total [###################...............................] 39.17%
# this epoch [#########################################.........] 83.33%
#       4700 iter, 7 epoch / 20 epochs
#     219.25 iters/sec. Estimated time to finish: 0:00:33.295214.
# 8           0.020384    0.0841953             0.993499       0.981                     21.9439
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       4800 iter, 8 epoch / 20 epochs
#     215.84 iters/sec. Estimated time to finish: 0:00:33.358021.
#      total [####################..............................] 40.83%
# this epoch [########..........................................] 16.67%
#       4900 iter, 8 epoch / 20 epochs
#     216.53 iters/sec. Estimated time to finish: 0:00:32.790319.
#      total [####################..............................] 41.67%
# this epoch [################..................................] 33.33%
#       5000 iter, 8 epoch / 20 epochs
#     217.22 iters/sec. Estimated time to finish: 0:00:32.225750.
#      total [#####################.............................] 42.50%
# this epoch [#########################.........................] 50.00%
#       5100 iter, 8 epoch / 20 epochs
#     217.87 iters/sec. Estimated time to finish: 0:00:31.669568.
#      total [#####################.............................] 43.33%
# this epoch [#################################.................] 66.67%
#       5200 iter, 8 epoch / 20 epochs
#     218.53 iters/sec. Estimated time to finish: 0:00:31.117634.
#      total [######################............................] 44.17%
# this epoch [#########################################.........] 83.33%
#       5300 iter, 8 epoch / 20 epochs
#     219.16 iters/sec. Estimated time to finish: 0:00:30.571968.
# 9           0.01565     0.0933678             0.994748       0.9798                    24.6882
#      total [######################............................] 45.00%
# this epoch [..................................................]  0.00%
#       5400 iter, 9 epoch / 20 epochs
#     216.15 iters/sec. Estimated time to finish: 0:00:30.534491.
#      total [######################............................] 45.83%
# this epoch [########..........................................] 16.67%
#       5500 iter, 9 epoch / 20 epochs
#     216.65 iters/sec. Estimated time to finish: 0:00:30.001685.
#      total [#######################...........................] 46.67%
# this epoch [################..................................] 33.33%
#       5600 iter, 9 epoch / 20 epochs
#     217.27 iters/sec. Estimated time to finish: 0:00:29.457071.
#      total [#######################...........................] 47.50%
# this epoch [#########################.........................] 50.00%
#       5700 iter, 9 epoch / 20 epochs
#     217.84 iters/sec. Estimated time to finish: 0:00:28.920085.
#      total [########################..........................] 48.33%
# this epoch [#################################.................] 66.67%
#       5800 iter, 9 epoch / 20 epochs
#     218.39 iters/sec. Estimated time to finish: 0:00:28.390203.
#      total [########################..........................] 49.17%
# this epoch [#########################################.........] 83.33%
#       5900 iter, 9 epoch / 20 epochs
#     218.92 iters/sec. Estimated time to finish: 0:00:27.864359.
# 10          0.0153762   0.112915              0.995249       0.9781                    27.4562
#      total [#########################.........................] 50.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 10 epoch / 20 epochs
#     216.36 iters/sec. Estimated time to finish: 0:00:27.731232.
#      total [#########################.........................] 50.83%
# this epoch [########..........................................] 16.67%
#       6100 iter, 10 epoch / 20 epochs
#     216.91 iters/sec. Estimated time to finish: 0:00:27.200160.
#      total [#########################.........................] 51.67%
# this epoch [################..................................] 33.33%
#       6200 iter, 10 epoch / 20 epochs
#     217.44 iters/sec. Estimated time to finish: 0:00:26.673491.
#      total [##########################........................] 52.50%
# this epoch [#########################.........................] 50.00%
#       6300 iter, 10 epoch / 20 epochs
#     217.95 iters/sec. Estimated time to finish: 0:00:26.152219.
#      total [##########################........................] 53.33%
# this epoch [#################################.................] 66.67%
#       6400 iter, 10 epoch / 20 epochs
#     218.45 iters/sec. Estimated time to finish: 0:00:25.635495.
#      total [###########################.......................] 54.17%
# this epoch [#########################################.........] 83.33%
#       6500 iter, 10 epoch / 20 epochs
#     218.95 iters/sec. Estimated time to finish: 0:00:25.119846.
# 11          0.0141951   0.0873361             0.995565       0.9803                    30.1982
#      total [###########################.......................] 55.00%
# this epoch [..................................................]  0.00%
#       6600 iter, 11 epoch / 20 epochs
#     216.59 iters/sec. Estimated time to finish: 0:00:24.931711.
#      total [###########################.......................] 55.83%
# this epoch [########..........................................] 16.67%
#       6700 iter, 11 epoch / 20 epochs
#     217.08 iters/sec. Estimated time to finish: 0:00:24.415289.
#      total [############################......................] 56.67%
# this epoch [################..................................] 33.33%
#       6800 iter, 11 epoch / 20 epochs
#     217.57 iters/sec. Estimated time to finish: 0:00:23.900841.
#      total [############################......................] 57.50%
# this epoch [#########################.........................] 50.00%
#       6900 iter, 11 epoch / 20 epochs
#     218.05 iters/sec. Estimated time to finish: 0:00:23.388729.
#      total [#############################.....................] 58.33%
# this epoch [#################################.................] 66.67%
#       7000 iter, 11 epoch / 20 epochs
#     218.53 iters/sec. Estimated time to finish: 0:00:22.880625.
#      total [#############################.....................] 59.17%
# this epoch [#########################################.........] 83.33%
#       7100 iter, 11 epoch / 20 epochs
#     218.98 iters/sec. Estimated time to finish: 0:00:22.376301.
# 12          0.0131632   0.105148              0.995815       0.979                     32.9329
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       7200 iter, 12 epoch / 20 epochs
#     216.76 iters/sec. Estimated time to finish: 0:00:22.144701.
#      total [##############################....................] 60.83%
# this epoch [########..........................................] 16.67%
#       7300 iter, 12 epoch / 20 epochs
#     217.21 iters/sec. Estimated time to finish: 0:00:21.637786.
#      total [##############################....................] 61.67%
# this epoch [################..................................] 33.33%
#       7400 iter, 12 epoch / 20 epochs
#     217.67 iters/sec. Estimated time to finish: 0:00:21.132914.
#      total [###############################...................] 62.50%
# this epoch [#########################.........................] 50.00%
#       7500 iter, 12 epoch / 20 epochs
#     218.11 iters/sec. Estimated time to finish: 0:00:20.631917.
#      total [###############################...................] 63.33%
# this epoch [#################################.................] 66.67%
#       7600 iter, 12 epoch / 20 epochs
#     218.45 iters/sec. Estimated time to finish: 0:00:20.142322.
#      total [################################..................] 64.17%
# this epoch [#########################################.........] 83.33%
#       7700 iter, 12 epoch / 20 epochs
#     218.87 iters/sec. Estimated time to finish: 0:00:19.646218.
# 13          0.0116338   0.0983813             0.996732       0.9807                    35.6844
#      total [################################..................] 65.00%
# this epoch [..................................................]  0.00%
#       7800 iter, 13 epoch / 20 epochs
#     216.89 iters/sec. Estimated time to finish: 0:00:19.364615.
#      total [################################..................] 65.83%
# this epoch [########..........................................] 16.67%
#       7900 iter, 13 epoch / 20 epochs
#      217.3 iters/sec. Estimated time to finish: 0:00:18.868221.
#      total [#################################.................] 66.67%
# this epoch [################..................................] 33.33%
#       8000 iter, 13 epoch / 20 epochs
#     217.72 iters/sec. Estimated time to finish: 0:00:18.372302.
#      total [#################################.................] 67.50%
# this epoch [#########################.........................] 50.00%
#       8100 iter, 13 epoch / 20 epochs
#     218.13 iters/sec. Estimated time to finish: 0:00:17.878838.
#      total [##################################................] 68.33%
# this epoch [#################################.................] 66.67%
#       8200 iter, 13 epoch / 20 epochs
#     218.52 iters/sec. Estimated time to finish: 0:00:17.389405.
#      total [##################################................] 69.17%
# this epoch [#########################################.........] 83.33%
#       8300 iter, 13 epoch / 20 epochs
#     218.91 iters/sec. Estimated time to finish: 0:00:16.902304.
# 14          0.0123872   0.104027              0.995998       0.9815                    38.4242
#      total [###################################...............] 70.00%
# this epoch [..................................................]  0.00%
#       8400 iter, 14 epoch / 20 epochs
#     216.66 iters/sec. Estimated time to finish: 0:00:16.615940.
#      total [###################################...............] 70.83%
# this epoch [########..........................................] 16.67%
#       8500 iter, 14 epoch / 20 epochs
#     217.05 iters/sec. Estimated time to finish: 0:00:16.125305.
#      total [###################################...............] 71.67%
# this epoch [################..................................] 33.33%
#       8600 iter, 14 epoch / 20 epochs
#     217.44 iters/sec. Estimated time to finish: 0:00:15.636578.
#      total [####################################..............] 72.50%
# this epoch [#########################.........................] 50.00%
#       8700 iter, 14 epoch / 20 epochs
#     217.81 iters/sec. Estimated time to finish: 0:00:15.150723.
#      total [####################################..............] 73.33%
# this epoch [#################################.................] 66.67%
#       8800 iter, 14 epoch / 20 epochs
#     218.18 iters/sec. Estimated time to finish: 0:00:14.666789.
#      total [#####################################.............] 74.17%
# this epoch [#########################################.........] 83.33%
#       8900 iter, 14 epoch / 20 epochs
#     218.54 iters/sec. Estimated time to finish: 0:00:14.184894.
# 15          0.0090647   0.0979302             0.996882       0.9828                    41.2334
#      total [#####################################.............] 75.00%
# this epoch [..................................................]  0.00%
#       9000 iter, 15 epoch / 20 epochs
#     216.76 iters/sec. Estimated time to finish: 0:00:13.839888.
#      total [#####################################.............] 75.83%
# this epoch [########..........................................] 16.67%
#       9100 iter, 15 epoch / 20 epochs
#     217.13 iters/sec. Estimated time to finish: 0:00:13.356036.
#      total [######################################............] 76.67%
# this epoch [################..................................] 33.33%
#       9200 iter, 15 epoch / 20 epochs
#      217.5 iters/sec. Estimated time to finish: 0:00:12.873578.
#      total [######################################............] 77.50%
# this epoch [#########################.........................] 50.00%
#       9300 iter, 15 epoch / 20 epochs
#     217.86 iters/sec. Estimated time to finish: 0:00:12.393358.
#      total [#######################################...........] 78.33%
# this epoch [#################################.................] 66.67%
#       9400 iter, 15 epoch / 20 epochs
#     218.21 iters/sec. Estimated time to finish: 0:00:11.915247.
#      total [#######################################...........] 79.17%
# this epoch [#########################################.........] 83.33%
#       9500 iter, 15 epoch / 20 epochs
#     218.54 iters/sec. Estimated time to finish: 0:00:11.439460.
# 16          0.0116575   0.090637              0.996682       0.9831                    43.9762
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#       9600 iter, 16 epoch / 20 epochs
#     216.84 iters/sec. Estimated time to finish: 0:00:11.068165.
#      total [########################################..........] 80.83%
# this epoch [########..........................................] 16.67%
#       9700 iter, 16 epoch / 20 epochs
#     217.08 iters/sec. Estimated time to finish: 0:00:10.595159.
#      total [########################################..........] 81.67%
# this epoch [################..................................] 33.33%
#       9800 iter, 16 epoch / 20 epochs
#     217.42 iters/sec. Estimated time to finish: 0:00:10.118633.
#      total [#########################################.........] 82.50%
# this epoch [#########################.........................] 50.00%
#       9900 iter, 16 epoch / 20 epochs
#     217.75 iters/sec. Estimated time to finish: 0:00:09.643939.
#      total [#########################################.........] 83.33%
# this epoch [#################################.................] 66.67%
#      10000 iter, 16 epoch / 20 epochs
#     218.08 iters/sec. Estimated time to finish: 0:00:09.171097.
#      total [##########################################........] 84.17%
# this epoch [#########################################.........] 83.33%
#      10100 iter, 16 epoch / 20 epochs
#     218.39 iters/sec. Estimated time to finish: 0:00:08.699854.
# 17          0.00839971  0.111332              0.997466       0.9798                    46.7533
#      total [##########################################........] 85.00%
# this epoch [..................................................]  0.00%
#      10200 iter, 17 epoch / 20 epochs
#     216.48 iters/sec. Estimated time to finish: 0:00:08.315016.
#      total [##########################################........] 85.83%
# this epoch [########..........................................] 16.67%
#      10300 iter, 17 epoch / 20 epochs
#     216.47 iters/sec. Estimated time to finish: 0:00:07.853334.
#      total [###########################################.......] 86.67%
# this epoch [################..................................] 33.33%
#      10400 iter, 17 epoch / 20 epochs
#     216.46 iters/sec. Estimated time to finish: 0:00:07.391829.
#      total [###########################################.......] 87.50%
# this epoch [#########################.........................] 50.00%
#      10500 iter, 17 epoch / 20 epochs
#     216.46 iters/sec. Estimated time to finish: 0:00:06.929729.
#      total [############################################......] 88.33%
# this epoch [#################################.................] 66.67%
#      10600 iter, 17 epoch / 20 epochs
#     218.26 iters/sec. Estimated time to finish: 0:00:06.414466.
#      total [############################################......] 89.17%
# this epoch [#########################################.........] 83.33%
#      10700 iter, 17 epoch / 20 epochs
#     218.27 iters/sec. Estimated time to finish: 0:00:05.956059.
# 18          0.0107938   0.107035              0.996782       0.9809                    49.5215
#      total [#############################################.....] 90.00%
# this epoch [..................................................]  0.00%
#      10800 iter, 18 epoch / 20 epochs
#     216.35 iters/sec. Estimated time to finish: 0:00:05.546479.
#      total [#############################################.....] 90.83%
# this epoch [########..........................................] 16.67%
#      10900 iter, 18 epoch / 20 epochs
#     216.35 iters/sec. Estimated time to finish: 0:00:05.084383.
#      total [#############################################.....] 91.67%
# this epoch [################..................................] 33.33%
#      11000 iter, 18 epoch / 20 epochs
#     216.36 iters/sec. Estimated time to finish: 0:00:04.621897.
#      total [##############################################....] 92.50%
# this epoch [#########################.........................] 50.00%
#      11100 iter, 18 epoch / 20 epochs
#     216.37 iters/sec. Estimated time to finish: 0:00:04.159533.
#      total [##############################################....] 93.33%
# this epoch [#################################.................] 66.67%
#      11200 iter, 18 epoch / 20 epochs
#     218.73 iters/sec. Estimated time to finish: 0:00:03.657438.
#      total [###############################################...] 94.17%
# this epoch [#########################################.........] 83.33%
#      11300 iter, 18 epoch / 20 epochs
#     218.73 iters/sec. Estimated time to finish: 0:00:03.200354.
# 19          0.00846774  0.106113              0.997616       0.9818                    52.2791
#      total [###############################################...] 95.00%
# this epoch [..................................................]  0.00%
#      11400 iter, 19 epoch / 20 epochs
#      216.8 iters/sec. Estimated time to finish: 0:00:02.767552.
#      total [###############################################...] 95.83%
# this epoch [########..........................................] 16.67%
#      11500 iter, 19 epoch / 20 epochs
#     216.77 iters/sec. Estimated time to finish: 0:00:02.306594.
#      total [################################################..] 96.67%
# this epoch [################..................................] 33.33%
#      11600 iter, 19 epoch / 20 epochs
#     216.77 iters/sec. Estimated time to finish: 0:00:01.845291.
#      total [################################################..] 97.50%
# this epoch [#########################.........................] 50.00%
#      11700 iter, 19 epoch / 20 epochs
#     216.76 iters/sec. Estimated time to finish: 0:00:01.383994.
#      total [#################################################.] 98.33%
# this epoch [#################################.................] 66.67%
#      11800 iter, 19 epoch / 20 epochs
#     218.65 iters/sec. Estimated time to finish: 0:00:00.914715.
#      total [#################################################.] 99.17%
# this epoch [#########################################.........] 83.33%
#      11900 iter, 19 epoch / 20 epochs
#     218.67 iters/sec. Estimated time to finish: 0:00:00.457303.
# 20          0.00863608  0.124237              0.997383       0.9789                    55.0333
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#      12000 iter, 20 epoch / 20 epochs
#     216.71 iters/sec. Estimated time to finish: 0:00:00.
