# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setting" data-toc-modified-id="Setting-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setting</a></span><ul class="toc-item"><li><span><a href="#Path" data-toc-modified-id="Path-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Path</a></span></li></ul></li><li><span><a href="#時系列データ作成" data-toc-modified-id="時系列データ作成-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>時系列データ作成</a></span></li><li><span><a href="#Adjust-Input-Shape" data-toc-modified-id="Adjust-Input-Shape-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><code>Adjust</code> Input Shape</a></span></li><li><span><a href="#Load-Model" data-toc-modified-id="Load-Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load <code>Model</code></a></span></li><li><span><a href="#Visualize-conv1d_1-Outputs" data-toc-modified-id="Visualize-conv1d_1-Outputs-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Visualize conv1d_1 Outputs</a></span><ul class="toc-item"><li><span><a href="#Get-Hidden-Layer-Outputs" data-toc-modified-id="Get-Hidden-Layer-Outputs-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Get Hidden Layer Outputs</a></span></li><li><span><a href="#ch-0" data-toc-modified-id="ch-0-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span><code>ch 0</code></a></span><ul class="toc-item"><li><span><a href="#ch-0-畳み込み層出力" data-toc-modified-id="ch-0-畳み込み層出力-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span><code>ch 0</code> 畳み込み層出力</a></span></li><li><span><a href="#Convolve-Layer-Output-畳み込み層の出力を畳み込む" data-toc-modified-id="Convolve-Layer-Output-畳み込み層の出力を畳み込む-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span><code>Convolve Layer Output</code> 畳み込み層の出力を畳み込む</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-5.2.2.1"><span class="toc-item-num">5.2.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li></ul></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span><ul class="toc-item"><li><span><a href="#考察" data-toc-modified-id="考察-5.2.3.1"><span class="toc-item-num">5.2.3.1&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li><li><span><a href="#All-Ch" data-toc-modified-id="All-Ch-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span><code>All Ch</code></a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-5.3.2.1"><span class="toc-item-num">5.3.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#考察" data-toc-modified-id="考察-5.3.2.2"><span class="toc-item-num">5.3.2.2&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#特徴をつかむ" data-toc-modified-id="特徴をつかむ-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>特徴をつかむ</a></span><ul class="toc-item"><li><span><a href="#ch-0" data-toc-modified-id="ch-0-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>ch 0</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#Convolve-Layer-Output-畳み込み層の出力を畳み込む" data-toc-modified-id="Convolve-Layer-Output-畳み込み層の出力を畳み込む-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span><code>Convolve Layer Output</code> 畳み込み層の出力を畳み込む</a></span></li><li><span><a href="#Plot" data-toc-modified-id="Plot-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-6.1.4.1"><span class="toc-item-num">6.1.4.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#考察" data-toc-modified-id="考察-6.1.4.2"><span class="toc-item-num">6.1.4.2&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li><li><span><a href="#ch-2" data-toc-modified-id="ch-2-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>ch 2</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#Convolve-Layer-Output-畳み込み層の出力を畳み込む" data-toc-modified-id="Convolve-Layer-Output-畳み込み層の出力を畳み込む-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span><code>Convolve Layer Output</code> 畳み込み層の出力を畳み込む</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-6.2.2.1"><span class="toc-item-num">6.2.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li></ul></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span></li><li><span><a href="#Plot" data-toc-modified-id="Plot-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Plot</a></span><ul class="toc-item"><li><span><a href="#考察" data-toc-modified-id="考察-6.2.4.1"><span class="toc-item-num">6.2.4.1&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Noise入りSin波を入力してみる" data-toc-modified-id="Noise入りSin波を入力してみる-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Noise入りSin波を入力してみる</a></span><ul class="toc-item"><li><span><a href="#Create-Data" data-toc-modified-id="Create-Data-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Create Data</a></span></li><li><span><a href="#Adjust-Shape" data-toc-modified-id="Adjust-Shape-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span><code>Adjust</code> Shape</a></span></li><li><span><a href="#Get-Hidden-Layer-Outputs" data-toc-modified-id="Get-Hidden-Layer-Outputs-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Get <code>Hidden</code> Layer Outputs</a></span></li><li><span><a href="#Visualize-Hidden-Output" data-toc-modified-id="Visualize-Hidden-Output-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span><code>Visualize</code> <code>Hidden</code> Output</a></span><ul class="toc-item"><li><span><a href="#ch-0-畳み込み層出力" data-toc-modified-id="ch-0-畳み込み層出力-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span><code>ch 0</code> 畳み込み層出力</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-7.4.1.1"><span class="toc-item-num">7.4.1.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#ch0-Convolve-Output" data-toc-modified-id="ch0-Convolve-Output-7.4.1.2"><span class="toc-item-num">7.4.1.2&nbsp;&nbsp;</span><code>ch0</code> <code>Convolve</code> Output</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-7.4.1.2.1"><span class="toc-item-num">7.4.1.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li></ul></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-7.4.1.3"><span class="toc-item-num">7.4.1.3&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span></li><li><span><a href="#考察" data-toc-modified-id="考察-7.4.1.4"><span class="toc-item-num">7.4.1.4&nbsp;&nbsp;</span>考察</a></span></li></ul></li><li><span><a href="#All-Ch" data-toc-modified-id="All-Ch-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span><code>All Ch</code></a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-7.4.2.1"><span class="toc-item-num">7.4.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-7.4.2.2"><span class="toc-item-num">7.4.2.2&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-7.4.2.2.1"><span class="toc-item-num">7.4.2.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li></ul></li><li><span><a href="#考察" data-toc-modified-id="考察-7.4.2.3"><span class="toc-item-num">7.4.2.3&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#パルス波-学習とは無関係な波形を入力" data-toc-modified-id="パルス波-学習とは無関係な波形を入力-8"><span class="toc-item-num">8&nbsp;&nbsp;</span><code>パルス波</code> 学習とは無関係な波形を入力</a></span><ul class="toc-item"><li><span><a href="#波形生成" data-toc-modified-id="波形生成-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span><code>波形生成</code></a></span></li><li><span><a href="#Adjust-Input-shape" data-toc-modified-id="Adjust-Input-shape-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span><code>Adjust</code> Input shape</a></span></li><li><span><a href="#Visualize-Conv1d-output" data-toc-modified-id="Visualize-Conv1d-output-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span><code>Visualize</code> Conv1d output</a></span><ul class="toc-item"><li><span><a href="#Get-Hidden-Layer-Outputs" data-toc-modified-id="Get-Hidden-Layer-Outputs-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Get Hidden Layer Outputs</a></span></li><li><span><a href="#Plot-0チャネル畳み込み層出力" data-toc-modified-id="Plot-0チャネル畳み込み層出力-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span><code>Plot</code> 0チャネル畳み込み層出力</a></span></li><li><span><a href="#Convolve-Layer-Output-畳み込み層の出力を畳み込む" data-toc-modified-id="Convolve-Layer-Output-畳み込み層の出力を畳み込む-8.3.3"><span class="toc-item-num">8.3.3&nbsp;&nbsp;</span><code>Convolve Layer Output</code> 畳み込み層の出力を畳み込む</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-8.3.3.1"><span class="toc-item-num">8.3.3.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li></ul></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-8.3.4"><span class="toc-item-num">8.3.4&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span><ul class="toc-item"><li><span><a href="#考察" data-toc-modified-id="考察-8.3.4.1"><span class="toc-item-num">8.3.4.1&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li><li><span><a href="#All-Ch" data-toc-modified-id="All-Ch-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span><code>All Ch</code></a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-8.4.1"><span class="toc-item-num">8.4.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#元波形との重ねあわせ" data-toc-modified-id="元波形との重ねあわせ-8.4.2"><span class="toc-item-num">8.4.2&nbsp;&nbsp;</span>元波形との重ねあわせ</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-8.4.2.1"><span class="toc-item-num">8.4.2.1&nbsp;&nbsp;</span><code>Plot</code></a></span></li><li><span><a href="#考察" data-toc-modified-id="考察-8.4.2.2"><span class="toc-item-num">8.4.2.2&nbsp;&nbsp;</span>考察</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#End" data-toc-modified-id="End-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>End</a></span></li></ul></div>

# %%
ipynb_title = "visualize_Conv1d_model__SimpleSinFuncWithNoNoise"
model_filename = "model__create_Conv1d_model__SimpleSinFuncWithNoNoise.h5"

# %%
aaa = 15

# %% [markdown]
# {{aaa}}

# %% [markdown]
# # {{ipynb_title}}
#
# 1. データ作成
#   - 単なるsin関数を含んだ式
#   - ノイズを加える
#   - 異常波形作成
# 1. CNN時系列予測
#   - [時系列予測を一次元畳み込みを使って解く with Keras - Qiita
#       ](https://qiita.com/niisan-tokyo/items/a94dbd3134219f19cab1)
#   - その背景を $windowsize$ 5-60程度で予測するConv1d層の作成

# %%
import os,sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path

import keras
print("Keras version : ", keras.__version__)
# Out:
# Keras version :  2.1.6

# %% [markdown]
# ## Setting

# %% [markdown]
# ### Path

# %%
HOME = Path(os.getcwd()).parent
print(HOME)
# Out:
# /home/pollen/workdir/git/github/article_script/20180719_visualize_Conv1d_output__in_kabuku

# %%
path_list = []
keras_model_h5_Path = HOME / "keras_model_h5"
path_list.append(keras_model_h5_Path)
data_Path = HOME / "data"
path_list.append(data_Path)
plot_images_Path = data_Path / "plot_images"
path_list.append(plot_images_Path)

for _Path in path_list:
    _path = str(_Path)
    if not os.path.exists(_path):
        os.makedirs(name=_path)
        print("make a directory: \n\t", _path)
    else:
        print(os.path.exists(_path), ": ", _path)
# Out:
# True :  /home/pollen/workdir/git/github/article_script/20180719_visualize_Conv1d_output__in_kabuku/keras_model_h5
# True :  /home/pollen/workdir/git/github/article_script/20180719_visualize_Conv1d_output__in_kabuku/data
# True :  /home/pollen/workdir/git/github/article_script/20180719_visualize_Conv1d_output__in_kabuku/data/plot_images

# %% [markdown]
# ## 時系列データ作成
#
# $$
# \textbf{toyfunc(t)} = \sin\left( \frac{2 \pi}{T} t \right)
# $$

# %%
def mySin(t, period=100):
    """
    時刻t, 周期period
    """
    return np.sin(2.0 * np.pi * t/period)

# %%
# Add Noise
def toy_func(tStart=0, tStop=100, tStep=1, noiseAmpl=0.05):
    """
    T : 
      sin波の周期
    ampl : 
      ノイズ振幅調整
      """
    t = np.arange(start=tStart, stop=tStop, step=tStep)
    noise = np.random.randn(t.shape[0])  # mean=0, standard_deviation=1
    return (t,
            + mySin(t=t, period=100)
            + noiseAmpl * noise )

# %% [markdown]
# ## `Adjust` Input Shape

# %%
tStart = 10000
windowsize = 100
predictsize = 1
wave_size = 300
assert wave_size - windowsize > windowsize  # 後に畳み込むにはこの条件が必要

# %%
filename = "{}__wave_with_noise.png".format(ipynb_title)

#----------------------------------------
# create a wave
#----------------------------------------
t, wave = toy_func(tStart=tStart, tStop=tStart+wave_size, noiseAmpl=0)

fig = plt.figure(figsize=(14,5))  # (width, height)
ax = fig.add_subplot(1,1,1)
ax.plot(t, wave)

title = "no noise"
ax.set_title(label=title, fontsize=30)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="y", fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=0.0, y=1.02)
ax.tick_params(labelsize=20)

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %%
#----------------------------------------
# create input data
#----------------------------------------
input_arr = np.empty(shape=(0, windowsize))
print(input_arr.shape)
for i in range( wave.shape[0] - (windowsize + predictsize) + 1 ):
    input_arr = np.append(arr=input_arr,
                           values=wave[i:(i+windowsize)].reshape(1, -1),
                           axis=0)
print("input_arr.shape  : ", input_arr.shape)
input_arr = input_arr.reshape((-1, windowsize, 1))
print("input_arr.shape  : ", input_arr.shape)
# Out:
# (0, 100)
# input_arr.shape  :  (200, 100)
# input_arr.shape  :  (200, 100, 1)

# %% [markdown]
# ## Load `Model`

# %%
from keras.models import load_model

# %%
modelpath = str(keras_model_h5_Path / model_filename)
model = load_model(filepath=modelpath)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 100, 8)            88
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 50, 8)             0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 50, 8)             648
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 10, 8)             0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 10, 8)             648
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1, 8)              0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1, 4)              324
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 1, 1)              33
# =================================================================
# Total params: 1,741
# Trainable params: 1,741
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Visualize conv1d_1 Outputs

# %% [markdown]
# ### Get Hidden Layer Outputs

# %%
from keras.models import Model
output_layer_name = model.layers[0].name
hidden_layer_model = Model(inputs=model.input,
                           outputs=model.get_layer(output_layer_name).output)

# %%
hidden_layer_output = hidden_layer_model.predict(x=input_arr)
print(hidden_layer_output.shape)
# Out:
# (200, 100, 8)

# %% [markdown]
# ### `ch 0`

# %% [markdown]
# #### `ch 0` 畳み込み層出力

# %%
ch = 0
assert ch < hidden_layer_output.shape[2]

# %%
#--------------------
# Resize
#--------------------
weights = hidden_layer_output[:, :, ch].squeeze()
print(weights.shape)
weights = weights.T
print(weights.shape)
# Out:
# (200, 100)
# (100, 200)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights))
print("min : ", np.min(weights))
max_abs = np.maximum(np.max(weights),
                     abs(np.min(weights))
                    )
print("max abs : ", max_abs)
# Out:
# max :  0.9953733
# min :  0.0
# max abs :  0.9953733

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__allWindow__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
figsize=(14, 7)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             #orientation='horizontal',
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
print(ax.get_xlim())
print(ax.get_ylim())
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
print(aspect)
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=20, y=1.3)
ax.set_xlabel(xlabel="t'", fontsize=15)
ax.set_ylabel(ylabel="windowsize index", fontsize=15, rotation=0)
ax.yaxis.set_label_coords(x=0.01, y=1.1)  # ylabel position
ax.tick_params(labelsize=20)  # tick fontsize

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()
# Out:
# (-0.5, 199.5)
# (99.5, -0.5)
# 0.33333333333333326

# %% [markdown]
# #### `Convolve Layer Output` 畳み込み層の出力を畳み込む
# 出力を畳み込むとはどういうことか.
# - 畳み込み層の出力を畳み込むことでwindowsizeごとに取り出す

# %% [markdown]
# <img src="./images/fig01.png">

# %%
figsize = (25, 10)
cmap = "seismic"

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

# %%
#----------------------------------------
# Convolved window size
#----------------------------------------
weights_tmp = hidden_layer_output[:, :, ch].squeeze()
weights_tmp = weights_tmp.T

# Prepare for convolved
weights = np.empty(shape=(0, wave_size - predictsize))
for window_idx in range(windowsize):
    _shape = weights_tmp.shape[1]
    # append last
    if window_idx < windowsize-1:
        _val = weights_tmp[-1, -windowsize+window_idx+1:]
        insert_arr = np.append(arr=weights_tmp[window_idx],
                               values=_val,
                               axis=None)
    else:
        insert_arr = weights_tmp[window_idx]

    # insert first
    _val = weights_tmp[0, :window_idx]
    insert_arr = np.insert(arr=insert_arr,
                           obj=[0 for i in range(window_idx)],
                           values=_val,
                           ).reshape(1, -1)
    # append to the array
    #print(weights.shape)
    #print(insert_arr.shape)
    weights = np.append(
        arr=weights,
        values=insert_arr,
        axis=0,
    )
print("weights.shape : ", weights.shape)
# Out:
# weights.shape :  (100, 299)

# %%
# Convolved
weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)
print("weights_convolve_windows.shape : ", weights_convolve_windows.shape)
# Out:
# weights_convolve_windows.shape :  (1, 299)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows))
print("min : ", np.min(weights_convolve_windows))
max_abs = np.maximum(np.max(weights_convolve_windows),
                     abs(np.min(weights_convolve_windows))
                    )
print("max abs : ", max_abs)
# Out:
# max :  80.68414935469627
# min :  0.0
# max abs :  80.68414935469627

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=25)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channel: {}".format(ch), fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
ax.tick_params(labelsize=20)
ax.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    
                                        
                                        

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# #### 元波形との重ねあわせ

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = ipynb_title + "__channel00__convolveWindows_with_wave"
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth="4", color="black")
#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax2.tick_params(labelsize=20)

xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax2.get_xlim()[1] - ax2.get_xlim()[0]) / (ax2.get_ylim()[0] - ax2.get_ylim()[1])
ax2.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>


fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# 上のグラフを見ると波形の急激な __下降__ 時に畳み込み層の出力が大きな値を示していることがわかります。

# %% [markdown]
# ### `All Ch`
# channel range : 0-{{hidden_layer_output.shape[2] - 1}}

# %%
#------------------------------------------------------------
# Convolve all channels
#------------------------------------------------------------
weights_convolve_windows_all_channels = np.empty(shape=(0, wave_size - predictsize))
channel_size = hidden_layer_output.shape[2]
for ch in range(channel_size):
    #----------------------------------------
    # Convolved window size
    #----------------------------------------
    weights_tmp = hidden_layer_output[:, :, ch].squeeze()
    weights_tmp = weights_tmp.T

    # Prepare for convolved
    weights = np.empty(shape=(0, wave_size-1))
    for window_idx in range(windowsize):
        _shape = weights_tmp.shape[1]
        # append last
        if window_idx < windowsize-1:
            _val = weights_tmp[-1, -windowsize+window_idx+1:]
            insert_arr = np.append(arr=weights_tmp[window_idx],
                                   values=_val,
                                   axis=None)
        else:
            insert_arr = weights_tmp[window_idx]

        # insert first
        _val = weights_tmp[0, :window_idx]
        insert_arr = np.insert(arr=insert_arr,
                               obj   =[0 for i in range(window_idx)],
                               values=_val,
                               ).reshape(1, -1)
        # append to the array
        #print(insert_arr.shape)
        weights = np.append(
            arr=weights,
            values=insert_arr,
            axis=0,
        )

    # Convolved
    weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)

    # Append
    weights_convolve_windows_all_channels = \
        np.append(arr   =weights_convolve_windows_all_channels,
                  values=weights_convolve_windows,
                  axis  =0)
print("weights_convolve_windows_all_channels.shape : ", weights_convolve_windows_all_channels.shape)
# Out:
# weights_convolve_windows_all_channels.shape :  (8, 299)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows_all_channels))
print("min : ", np.min(weights_convolve_windows_all_channels))
max_abs = np.maximum(np.max(weights_convolve_windows_all_channels),
                     abs(np.min(weights_convolve_windows_all_channels))
                    )
print("max abs : ", max_abs)
# Out:
# max :  188.40374386310577
# min :  0.0
# max abs :  188.40374386310577

# %% [markdown]
# #### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__AllChannel__ConvolveWindows_windowsize_{}".format(ipynb_title, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows_all_channels,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 2  # <width> / <height>
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax.set_title(label=title, fontsize=25)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax.tick_params(labelsize=20)
## y ticks
ax.set_yticks(ticks=np.arange(channel_size))
ax.set_yticklabels(labels=[i if i%10==0 else "" for i in range(channel_size)])

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# #### 元波形との重ねあわせ

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__AllChannel__ConvolveWindows_with_wave__windowsize_{}".format(ipynb_title, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows_all_channels,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 2  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.set_yticks(ticks=np.arange(channel_size))
#ax1.set_yticklabels(labels=[i if i%10==0 else "" for i in range(channel_size)])
ax1.set_yticklabels(labels=[i if i%2==0 else "" for i in range(channel_size)])

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth=4, color="black")
ax2.tick_params(labelsize=20)

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察

# %% [markdown]
# ## 特徴をつかむ
# 全体図から上昇や下降している箇所で出力値の高い値を取得してチャネルごとに表示してみます.
# - channel range : 0-{{hidden_layer_output.shape[2] - 1}}

# %% [markdown]
# ### ch 0
# - channel range : 0-{{hidden_layer_output.shape[2] - 1}}

# %% [markdown]
# #### `Plot`

# %%
ch = 0
assert ch < hidden_layer_output.shape[2]

# %%
#--------------------
# Resize
#--------------------
weights = hidden_layer_output[:, :, ch].squeeze()
print(weights.shape)
weights = weights.T
print(weights.shape)

#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights))
print("min : ", np.min(weights))
max_abs = np.maximum(np.max(weights),
                     abs(np.min(weights))
                    )
print("max abs : ", max_abs)

#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}_allWindow__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
figsize=(14, 7)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             #orientation='horizontal',
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
print(ax.get_xlim())
print(ax.get_ylim())
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
print(aspect)
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=20, y=1.5)
ax.set_xlabel(xlabel="t'", fontsize=15)
ax.set_ylabel(ylabel="windowsize index", fontsize=15, rotation=0)
ax.yaxis.set_label_coords(x=0.01, y=1.1)  # ylabel position
ax.tick_params(labelsize=20)  # tick fontsize

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()
# Out:
# (200, 100)
# (100, 200)
# max :  0.9953733
# min :  0.0
# max abs :  0.9953733
# (-0.5, 199.5)
# (99.5, -0.5)
# 0.33333333333333326

# %% [markdown]
# #### `Convolve Layer Output` 畳み込み層の出力を畳み込む

# %%
#----------------------------------------
# Convolved window size
#----------------------------------------
weights_tmp = hidden_layer_output[:, :, ch].squeeze()
weights_tmp = weights_tmp.T

# Prepare for convolved
weights = np.empty(shape=(0, wave_size - predictsize))
for window_idx in range(windowsize):
    _shape = weights_tmp.shape[1]
    # append last
    if window_idx < windowsize-1:
        _val = weights_tmp[-1, -windowsize+window_idx+1:]
        insert_arr = np.append(arr=weights_tmp[window_idx],
                               values=_val,
                               axis=None)
    else:
        insert_arr = weights_tmp[window_idx]

    # insert first
    _val = weights_tmp[0, :window_idx]
    insert_arr = np.insert(arr=insert_arr,
                           obj   =[0 for i in range(window_idx)],
                           values=_val,
                           ).reshape(1, -1)
    # append to the array
    #print(insert_arr.shape)
    weights = np.append(
        arr=weights,
        values=insert_arr,
        axis=0,
    )
print("weights.shape : ", weights.shape)

# Convolved
weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)
print("weights_convolve_windows.shape : ", weights_convolve_windows.shape)

#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows))
print("min : ", np.min(weights_convolve_windows))
max_abs = np.maximum(np.max(weights_convolve_windows),
                     abs(np.min(weights_convolve_windows))
                    )
print("max abs : ", max_abs)
# Out:
# weights.shape :  (100, 299)
# weights_convolve_windows.shape :  (1, 299)
# max :  80.68414935469627
# min :  0.0
# max abs :  80.68414935469627

# %% [markdown]
# #### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=25, y=1.5)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channel: {}".format(ch), fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
ax.tick_params(labelsize=20)
ax.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    
                                        
                                        

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# #### 元波形との重ねあわせ

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows_with_wave__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth="4", color="black")
#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax2.tick_params(labelsize=20)

xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax2.get_xlim()[1] - ax2.get_xlim()[0]) / (ax2.get_ylim()[0] - ax2.get_ylim()[1])
ax2.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>


fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# 上のグラフを見ると波形の急激な __上昇__ 時に畳み込み層の出力が大きな値を示していることがわかります。

# %% [markdown]
# ### ch 2

# %% [markdown]
# #### `Plot`

# %%
ch = 2
assert ch < hidden_layer_output.shape[2]

# %%
#--------------------
# Resize
#--------------------
weights = hidden_layer_output[:, :, ch].squeeze()
print(weights.shape)
weights = weights.T
print(weights.shape)

#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights))
print("min : ", np.min(weights))
max_abs = np.maximum(np.max(weights),
                     abs(np.min(weights))
                    )
print("max abs : ", max_abs)

#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = ipynb_title + "__" + "channel{}_allWindow".format(ch)
filename = title + ".png"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
figsize=(14, 7)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             #orientation='horizontal',
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
print(ax.get_xlim())
print(ax.get_ylim())
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
print(aspect)
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=20, y=1.3)
ax.set_xlabel(xlabel="t'", fontsize=15)
ax.set_ylabel(ylabel="windowsize index", fontsize=15, rotation=0)
ax.yaxis.set_label_coords(x=0.01, y=1.1)  # ylabel position
ax.tick_params(labelsize=20)  # tick fontsize

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()
# Out:
# (200, 100)
# (100, 200)
# max :  1.3896399
# min :  0.0
# max abs :  1.3896399
# (-0.5, 199.5)
# (99.5, -0.5)
# 0.33333333333333326

# %% [markdown]
# #### `Convolve Layer Output` 畳み込み層の出力を畳み込む

# %%
#----------------------------------------
# Convolved window size
#----------------------------------------
weights_tmp = hidden_layer_output[:, :, ch].squeeze()
weights_tmp = weights_tmp.T

# Prepare for convolved
weights = np.empty(shape=(0, wave_size - predictsize))
for window_idx in range(windowsize):
    _shape = weights_tmp.shape[1]
    # append last
    if window_idx < windowsize-1:
        _val = weights_tmp[-1, -windowsize+window_idx+1:]
        insert_arr = np.append(arr=weights_tmp[window_idx],
                               values=_val,
                               axis=None)
    else:
        insert_arr = weights_tmp[window_idx]

    # insert first
    _val = weights_tmp[0, :window_idx]
    insert_arr = np.insert(arr=insert_arr,
                           obj   =[0 for i in range(window_idx)],
                           values=_val,
                           ).reshape(1, -1)
    # append to the array
    #print(insert_arr.shape)
    weights = np.append(
        arr=weights,
        values=insert_arr,
        axis=0,
    )
print("weights.shape : ", weights.shape)

# Convolved
weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)
print("weights_convolve_windows.shape : ", weights_convolve_windows.shape)

#--------------------
# get max value for plot ylim
#--------------------
print("max : ", np.max(weights_convolve_windows))
print("min : ", np.min(weights_convolve_windows))
max_abs = np.maximum(np.max(weights_convolve_windows),
                     abs(np.min(weights_convolve_windows))
                    )
print("max abs : ", max_abs)
# Out:
# weights.shape :  (100, 299)
# weights_convolve_windows.shape :  (1, 299)
# max :  135.5755307674408
# min :  0.0
# max abs :  135.5755307674408

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=25, y=1.2)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channel: {}".format(ch), fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
ax.tick_params(labelsize=20)
ax.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    
                                        
                                        

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# #### 元波形との重ねあわせ

# %% [markdown]
# #### Plot

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows_with_wave__windowsize_{}".format(ipynb_title, ch, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth="4", color="black")

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax2.get_xlim()[1] - ax2.get_xlim()[0]) / (ax2.get_ylim()[0] - ax2.get_ylim()[1])
ax2.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax2.tick_params(labelsize=20)

xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax2.get_xlim()[1] - ax2.get_xlim()[0]) / (ax2.get_ylim()[0] - ax2.get_ylim()[1])
ax2.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>


fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# 上のグラフを見ると波形の急激な __下降__ 時に畳み込み層の出力が大きな値を示していることがわかります。

# %% [markdown]
# ## Noise入りSin波を入力してみる

# %%
tStart = 10000
windowsize = 100
predictsize = 1
wave_size = 300
assert wave_size - windowsize > windowsize  # 後に畳み込むにはこの条件が必要

# %% [markdown]
# ### Create Data

# %%
def mySin(t, period=100):
    """
    時刻t, 周期period
    """
    return np.sin(2.0 * np.pi * t/period)

# Add Noise
def toy_func(tStart=0, tStop=100, tStep=1, noiseAmpl=0.05):
    """
    T : 
      sin波の周期
    ampl : 
      ノイズ振幅調整
      """
    t = np.arange(start=tStart, stop=tStop, step=tStep)
    noise = np.random.randn(t.shape[0])  # mean=0, standard_deviation=1
    return (t,
            + mySin(t=t, period=100)
            + noiseAmpl * noise )

# %%
filename = "{}__wave_with_noise.png".format(ipynb_title)

#----------------------------------------
# create a wave
#----------------------------------------
t, wave = toy_func(tStart=tStart, tStop=tStart+wave_size, noiseAmpl=0.1)

fig = plt.figure(figsize=(14,5))  # (width, height)
ax = fig.add_subplot(1,1,1)
ax.plot(t, wave)

title = "wave with noise"
ax.set_title(label=title, fontsize=30)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="y", fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=0.0, y=1.02)
ax.tick_params(labelsize=20)

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ### `Adjust` Shape

# %%
#----------------------------------------
# create input data
#----------------------------------------
input_arr = np.empty(shape=(0, windowsize))
print(input_arr.shape)
for i in range( wave.shape[0] - (windowsize + predictsize) + 1 ):
    input_arr = np.append(arr=input_arr,
                           values=wave[i:(i+windowsize)].reshape(1, -1),
                           axis=0)
print("input_arr.shape  : ", input_arr.shape)
input_arr = input_arr.reshape((-1, windowsize, 1))
print("input_arr.shape  : ", input_arr.shape)
# Out:
# (0, 100)
# input_arr.shape  :  (200, 100)
# input_arr.shape  :  (200, 100, 1)

# %% [markdown]
# ### Get `Hidden` Layer Outputs

# %%
from keras.models import Model
output_layer_name = model.layers[0].name
hidden_layer_model = Model(inputs=model.input,
                           outputs=model.get_layer(output_layer_name).output)

# %%
hidden_layer_output = hidden_layer_model.predict(x=input_arr)
print(hidden_layer_output.shape)
# Out:
# (200, 100, 8)

# %% [markdown]
# ### `Visualize` `Hidden` Output

# %% [markdown]
# #### `ch 0` 畳み込み層出力

# %%
ch = 0
assert ch < hidden_layer_output.shape[2]

# %% [markdown]
# ##### `Plot`

# %%
##--------------------
# Resize
#--------------------
weights = hidden_layer_output[:, :, ch].squeeze()
print(weights.shape)
weights = weights.T
print(weights.shape)

#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights))
print("min : ", np.min(weights))
max_abs = np.maximum(np.max(weights),
                     abs(np.min(weights))
                    )
print("max abs : ", max_abs)

#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__allWindow__windowsize_{}__passSimpleSinWave".format(ipynb_title, ch, windowsize)
filename = title + ".png"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
figsize=(14, 7)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             #orientation='horizontal',
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
print(ax.get_xlim())
print(ax.get_ylim())
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
print(aspect)
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=20, y=1.3)
ax.set_xlabel(xlabel="t'", fontsize=15)
ax.set_ylabel(ylabel="windowsize index", fontsize=15, rotation=0)
ax.yaxis.set_label_coords(x=0.01, y=1.1)  # ylabel position
ax.tick_params(labelsize=20)  # tick fontsize

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()
# Out:
# (200, 100)
# (100, 200)
# max :  1.102073
# min :  0.0
# max abs :  1.102073
# (-0.5, 199.5)
# (99.5, -0.5)
# 0.33333333333333326

# %% [markdown]
# ##### `ch0` `Convolve` Output

# %%
figsize = (25, 10)
cmap = "seismic"

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows__windowsize_{}__passSimpleSinWave".format(ipynb_title, ch, windowsize)
filename = title + ".png"

# %%
#----------------------------------------
# Convolved window size
#----------------------------------------
weights_tmp = hidden_layer_output[:, :, ch].squeeze()
weights_tmp = weights_tmp.T

# Prepare for convolved
weights = np.empty(shape=(0, wave_size - predictsize))
for window_idx in range(windowsize):
    _shape = weights_tmp.shape[1]
    # append last
    if window_idx < windowsize-1:
        _val = weights_tmp[-1, -windowsize+window_idx+1:]
        insert_arr = np.append(arr=weights_tmp[window_idx],
                               values=_val,
                               axis=None)
    else:
        insert_arr = weights_tmp[window_idx]

    # insert first
    _val = weights_tmp[0, :window_idx]
    insert_arr = np.insert(arr=insert_arr,
                           obj=[0 for i in range(window_idx)],
                           values=_val,
                           ).reshape(1, -1)
    # append to the array
    #print(weights.shape)
    #print(insert_arr.shape)
    weights = np.append(
        arr=weights,
        values=insert_arr,
        axis=0,
    )
print("weights.shape : ", weights.shape)
# Out:
# weights.shape :  (100, 299)

# %%
# Convolved
weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)
print("weights_convolve_windows.shape : ", weights_convolve_windows.shape)
# Out:
# weights_convolve_windows.shape :  (1, 299)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows))
print("min : ", np.min(weights_convolve_windows))
max_abs = np.maximum(np.max(weights_convolve_windows),
                     abs(np.min(weights_convolve_windows))
                    )
print("max abs : ", max_abs)
# Out:
# max :  86.28354048728943
# min :  0.0
# max abs :  86.28354048728943

# %% [markdown]
# ###### `Plot`

# %%
#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=25, y=1.2)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channel: {}".format(ch), fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
ax.tick_params(labelsize=20)
ax.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    
                                        
                                        

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 元波形との重ねあわせ

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows_with_wave__passSimpleSinWave".format(ipynb_title, ch)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth="4", color="black")
#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax2.tick_params(labelsize=20)

xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax2.get_xlim()[1] - ax2.get_xlim()[0]) / (ax2.get_ylim()[0] - ax2.get_ylim()[1])
ax2.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>


fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# ???

# %% [markdown]
# #### `All Ch`

# %%
#------------------------------------------------------------
# Convolve all channels
#------------------------------------------------------------
weights_convolve_windows_all_channels = np.empty(shape=(0, wave_size - predictsize))
channel_size = hidden_layer_output.shape[2]
for ch in range(channel_size):
    #----------------------------------------
    # Convolved window size
    #----------------------------------------
    weights_tmp = hidden_layer_output[:, :, ch].squeeze()
    weights_tmp = weights_tmp.T

    # Prepare for convolved
    weights = np.empty(shape=(0, wave_size-1))
    for window_idx in range(windowsize):
        _shape = weights_tmp.shape[1]
        # append last
        if window_idx < windowsize-1:
            _val = weights_tmp[-1, -windowsize+window_idx+1:]
            insert_arr = np.append(arr=weights_tmp[window_idx],
                                   values=_val,
                                   axis=None)
        else:
            insert_arr = weights_tmp[window_idx]

        # insert first
        _val = weights_tmp[0, :window_idx]
        insert_arr = np.insert(arr=insert_arr,
                               obj   =[0 for i in range(window_idx)],
                               values=_val,
                               ).reshape(1, -1)
        # append to the array
        #print(insert_arr.shape)
        weights = np.append(
            arr=weights,
            values=insert_arr,
            axis=0,
        )

    # Convolved
    weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)

    # Append
    weights_convolve_windows_all_channels = \
        np.append(arr   =weights_convolve_windows_all_channels,
                  values=weights_convolve_windows,
                  axis  =0)
print("weights_convolve_windows_all_channels.shape : ", weights_convolve_windows_all_channels.shape)
# Out:
# weights_convolve_windows_all_channels.shape :  (8, 299)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows_all_channels))
print("min : ", np.min(weights_convolve_windows_all_channels))
max_abs = np.maximum(np.max(weights_convolve_windows_all_channels),
                     abs(np.min(weights_convolve_windows_all_channels))
                    )
print("max abs : ", max_abs)
# Out:
# max :  193.50546550750732
# min :  0.0
# max abs :  193.50546550750732

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__AllChannel__ConvolveWindows_windowsize_{}__passSimpleSinWave".format(ipynb_title, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows_all_channels,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 2  # <width> / <height>
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax.set_title(label=title, fontsize=25, y=1.1)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax.tick_params(labelsize=20)
## y ticks
ax.set_yticks(ticks=np.arange(channel_size))
ax.set_yticklabels(labels=[i if i%10==0 else "" for i in range(channel_size)])

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 元波形との重ねあわせ

# %% [markdown]
# ###### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__AllChannel__ConvolveWindows_with_wave__windowsize_{}__passSimpleSinWave".format(ipynb_title, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows_all_channels,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 2  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.set_yticks(ticks=np.arange(channel_size))
ax1.set_yticklabels(labels=[i if i%10==0 else "" for i in range(channel_size)])

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth=4, color="black")
ax2.tick_params(labelsize=20)

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# ???

# %% [markdown]
# ## `パルス波` 学習とは無関係な波形を入力

# %% [markdown]
# ### `波形生成`

# %%
tStart = 10000
windowsize = 100
predictsize = 1
wave_size = 300
assert wave_size - windowsize > windowsize  # 後に畳み込むにはこの条件が必要

# %%
def mySin(t, period=100):
    """
    時刻t, 周期period
    """
    return np.sin(2.0 * np.pi * t/period)

# Add Noise
def toy_func(tStart=0, tStop=100, tStep=1, noiseAmpl=0.05):
    t = np.arange(start=tStart, stop=tStop, step=tStep)
    noise = np.random.randn(t.shape[0])  # mean=0, standard_deviation=1
    values = mySin(t, period=100)
    values[values < 0] *= 0
    return (t, values + noiseAmpl * noise )

# %%
t, wave = toy_func(tStart=tStart, tStop=tStart+wave_size, noiseAmpl=0)

# %%
fig = plt.figure(figsize=(14,7))
ax = fig.add_subplot(1,1,1)
ax.plot(t, wave)
plt.show()

# %% [markdown]
# ### `Adjust` Input shape

# %%
input_arr = np.empty(shape=(0, windowsize))
print(input_arr.shape)
for i in range( wave.shape[0] - (windowsize + predictsize) + 1 ):
    input_arr = np.append(arr=input_arr,
                           values=wave[i:(i+windowsize)].reshape(1, -1),
                           axis=0)
print("input_arr.shape  : ", input_arr.shape)
input_arr = input_arr.reshape((-1, windowsize, 1))
print("input_arr.shape  : ", input_arr.shape)
# Out:
# (0, 100)
# input_arr.shape  :  (200, 100)
# input_arr.shape  :  (200, 100, 1)

# %% [markdown]
# ### `Visualize` Conv1d output

# %% [markdown]
# #### Get Hidden Layer Outputs

# %%
from keras.models import Model
output_layer_name = model.layers[0].name
hidden_layer_model = Model(inputs=model.input,
                           outputs=model.get_layer(output_layer_name).output)

# %%
hidden_layer_output = hidden_layer_model.predict(x=input_arr)
print(hidden_layer_output.shape)
# Out:
# (200, 100, 8)

# %% [markdown]
# #### `Plot` 0チャネル畳み込み層出力

# %%
ch = 0

# %%
#--------------------
# Resize
#--------------------
weights = hidden_layer_output[:, :, ch].squeeze()
print(weights.shape)
weights = weights.T
print(weights.shape)
# Out:
# (200, 100)
# (100, 200)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights))
print("min : ", np.min(weights))
max_abs = np.maximum(np.max(weights),
                     abs(np.min(weights))
                    )
print("max abs : ", max_abs)
# Out:
# max :  0.9953733
# min :  0.078571014
# max abs :  0.9953733

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__allWindow__windowsize_{}__passSimpleSinWave".format(ipynb_title, ch, windowsize)
filename = title + ".png"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
figsize=(14, 7)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             #orientation='horizontal',
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
print(ax.get_xlim())
print(ax.get_ylim())
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
print(aspect)
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=20, y=1.3)
ax.set_xlabel(xlabel="t'", fontsize=15)
ax.set_ylabel(ylabel="windowsize index", fontsize=15, rotation=0)
ax.yaxis.set_label_coords(x=0.01, y=1.1)  # ylabel position
ax.tick_params(labelsize=20)  # tick fontsize

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()
# Out:
# (-0.5, 199.5)
# (99.5, -0.5)
# 0.33333333333333326

# %% [markdown]
# #### `Convolve Layer Output` 畳み込み層の出力を畳み込む

# %%
figsize = (25, 10)
cmap = "seismic"

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows__windowsize_{}__passSimpleSinWave".format(ipynb_title, ch, windowsize)
filename = title + ".png"

# %%
#----------------------------------------
# Convolved window size
#----------------------------------------
weights_tmp = hidden_layer_output[:, :, ch].squeeze()
weights_tmp = weights_tmp.T

# Prepare for convolved
weights = np.empty(shape=(0, wave_size - predictsize))
for window_idx in range(windowsize):
    _shape = weights_tmp.shape[1]
    # append last
    if window_idx < windowsize-1:
        _val = weights_tmp[-1, -windowsize+window_idx+1:]
        insert_arr = np.append(arr=weights_tmp[window_idx],
                               values=_val,
                               axis=None)
    else:
        insert_arr = weights_tmp[window_idx]

    # insert first
    _val = weights_tmp[0, :window_idx]
    insert_arr = np.insert(arr=insert_arr,
                           obj=[0 for i in range(window_idx)],
                           values=_val,
                           ).reshape(1, -1)
    # append to the array
    #print(weights.shape)
    #print(insert_arr.shape)
    weights = np.append(
        arr=weights,
        values=insert_arr,
        axis=0,
    )
print("weights.shape : ", weights.shape)
# Out:
# weights.shape :  (100, 299)

# %%
# Convolved
weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)
print("weights_convolve_windows.shape : ", weights_convolve_windows.shape)
# Out:
# weights_convolve_windows.shape :  (1, 299)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows))
print("min : ", np.min(weights_convolve_windows))
max_abs = np.maximum(np.max(weights_convolve_windows),
                     abs(np.min(weights_convolve_windows))
                    )
print("max abs : ", max_abs)
# Out:
# max :  80.68414935469627
# min :  8.724872805178165
# max abs :  80.68414935469627

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# height is aspect_num times the width
xratio = 6
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)

#----------------------------------------
# plot config
#----------------------------------------
ax.set_title(label=title, fontsize=25, y=1.2)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channel: {}".format(ch), fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
ax.tick_params(labelsize=20)
ax.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    
                                        
                                        

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# #### 元波形との重ねあわせ

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__channel{}__convolveWindows_with_wave__passSimpleSinWave".format(ipynb_title, ch)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.tick_params(axis ='y',        # changes apply to the x-axis
               which="both",     # both major and minor ticks are affected
               left =False,      # ticks along the bottom edge are off
               labelleft=False)  # labels along the bottom edge are off
               # ref: https://stackoverflow.com/questions/12998430/remove-xticks-in-a-matplotlib-plot    

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth="4", color="black")
#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax2.tick_params(labelsize=20)

xratio = 3  # <width> / <height>
aspect = (1/xratio) * (ax2.get_xlim()[1] - ax2.get_xlim()[0]) / (ax2.get_ylim()[0] - ax2.get_ylim()[1])
ax2.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>


fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# ???

# %% [markdown]
# ### `All Ch`

# %%
#------------------------------------------------------------
# Convolve all channels
#------------------------------------------------------------
weights_convolve_windows_all_channels = np.empty(shape=(0, wave_size - predictsize))
channel_size = hidden_layer_output.shape[2]
for ch in range(channel_size):
    #----------------------------------------
    # Convolved window size
    #----------------------------------------
    weights_tmp = hidden_layer_output[:, :, ch].squeeze()
    weights_tmp = weights_tmp.T

    # Prepare for convolved
    weights = np.empty(shape=(0, wave_size-1))
    for window_idx in range(windowsize):
        _shape = weights_tmp.shape[1]
        # append last
        if window_idx < windowsize-1:
            _val = weights_tmp[-1, -windowsize+window_idx+1:]
            insert_arr = np.append(arr=weights_tmp[window_idx],
                                   values=_val,
                                   axis=None)
        else:
            insert_arr = weights_tmp[window_idx]

        # insert first
        _val = weights_tmp[0, :window_idx]
        insert_arr = np.insert(arr=insert_arr,
                               obj   =[0 for i in range(window_idx)],
                               values=_val,
                               ).reshape(1, -1)
        # append to the array
        #print(insert_arr.shape)
        weights = np.append(
            arr=weights,
            values=insert_arr,
            axis=0,
        )

    # Convolved
    weights_convolve_windows = weights.sum(axis=0).reshape(1, -1)

    # Append
    weights_convolve_windows_all_channels = \
        np.append(arr   =weights_convolve_windows_all_channels,
                  values=weights_convolve_windows,
                  axis  =0)
print("weights_convolve_windows_all_channels.shape : ", weights_convolve_windows_all_channels.shape)
# Out:
# weights_convolve_windows_all_channels.shape :  (8, 299)

# %%
#--------------------
# get max value for plot Color
#--------------------
print("max : ", np.max(weights_convolve_windows_all_channels))
print("min : ", np.min(weights_convolve_windows_all_channels))
max_abs = np.maximum(np.max(weights_convolve_windows_all_channels),
                     abs(np.min(weights_convolve_windows_all_channels))
                    )
print("max abs : ", max_abs)
# Out:
# max :  154.18997931480408
# min :  0.0
# max abs :  154.18997931480408

# %% [markdown]
# #### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__AllChannel__ConvolveWindows_windowsize_{}__passSimpleSinWave".format(ipynb_title, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
mappable = ax.imshow(weights_convolve_windows_all_channels,
                     cmap='seismic',  # <-- (min,max)=(blue, red)
                     vmin=-max_abs,
                     vmax=max_abs,
                     )
fig.colorbar(mappable,
             ax=ax,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 2  # <width> / <height>
aspect = (1/xratio) * (ax.get_xlim()[1] - ax.get_xlim()[0]) / (ax.get_ylim()[0] - ax.get_ylim()[1])
ax.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax.set_title(label=title, fontsize=25, y=1.1)
ax.set_xlabel(xlabel="t", fontsize=20)
ax.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax.tick_params(labelsize=20)
## y ticks
ax.set_yticks(ticks=np.arange(channel_size))
ax.set_yticklabels(labels=[i if i%10==0 else "" for i in range(channel_size)])

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# #### 元波形との重ねあわせ

# %% [markdown]
# ##### `Plot`

# %%
#--------------------------------------------------------------------------------
# Setting Parameter
#--------------------------------------------------------------------------------
title = "{}__AllChannel__ConvolveWindows_with_wave__windowsize_{}__passSimpleSinWave".format(ipynb_title, windowsize)
filename = title + ".png"

figsize = (25, 10)
cmap = "seismic"

#--------------------------------------------------------------------------------
# Plot
#--------------------------------------------------------------------------------
fig = plt.figure(figsize=figsize)

#------------------------------------------------------------
# weights
#------------------------------------------------------------
ax1 = fig.add_subplot(1,1,1)
mappable = ax1.imshow(weights_convolve_windows_all_channels,
                      cmap='seismic',  # <-- (min,max)=(blue, red)
                      vmin=-max_abs,
                      vmax=max_abs,
                      )
fig.colorbar(mappable,
             ax=ax1,
             orientation='vertical',
             shrink=0.5,
             )

#----------------------------------------
# change x,y axis ratio
#----------------------------------------
# ref:
#   - http://yama-sampo.hatenablog.com/entry/2017/12/21/195519
xratio = 2  # <width> / <height>
aspect = (1/xratio) * (ax1.get_xlim()[1] - ax1.get_xlim()[0]) / (ax1.get_ylim()[0] - ax1.get_ylim()[1])
ax1.set_aspect(aspect=aspect,)  # <height> = <aspect_num> x <width>

#----------------------------------------
# plot config
#----------------------------------------
## title & axis labels
ax1.set_title(label=title, fontsize=25, y=1.1)
ax1.set_xlabel(xlabel="t", fontsize=20)
ax1.set_ylabel(ylabel="Channels", fontsize=20, rotation=0)
ax1.yaxis.set_label_coords(x=-0.02, y=1.04)
## ticks
ax1.tick_params(labelsize=20)
## y ticks
ax1.set_yticks(ticks=np.arange(channel_size))
ax1.set_yticklabels(labels=[i if i%10==0 else "" for i in range(channel_size)])

#------------------------------------------------------------
# wave
#------------------------------------------------------------
ax2 = ax1.twinx()
ax2.yaxis.tick_right()                          # y軸を右に指定
ax2.yaxis.set_label_position(position="right")  # y軸のラベルを右に指定
ax2.plot(np.arange(wave_size - predictsize), wave[:wave_size - predictsize],
         linewidth=4, color="black")
ax2.tick_params(labelsize=20)

fig.savefig(fname=str(plot_images_Path / filename))
plt.show()

# %% [markdown]
# ##### 考察
# ???

# %% [markdown]
# ## End
